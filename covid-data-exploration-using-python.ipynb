# %% [markdown]
# ## Project Overview:

# %% [markdown]
# The Covid-19 Pandemic affected everyone in the world, as many lives were lost, and everyones' daily routines were drastically upended.
#
# It is important to analyze Covid-19 Data inorder to predict what may happen in a future pandemic, and if vaccinations really are effective in saving peoples lives.

# %% [markdown]
# **Here is what important tasks we can analyze from Covid-19 world data:**
# * Exploring the content available
# * Cleaning the data for analysis
# * Understanding the amount of people who contracted Covid-19 by country
# * Discovering the percentage of people per country who were fully vaccinated
# * Understanding the impact of becoming vaccinated. Did Covid-19 cases drop once people were vaccinated?

# %% [markdown]
# **Covid-19 Data with Python:**
#
# The dataset I used for Covid-19 analytics was provided by the Our World in Data Organization. This dataset is consistently updated which is important so we have current data to analyze.

# %% [markdown]
# **Analyzing the data sets:**
# Importing the dataset and the Python libraries necessary for this task.

# %%
import numpy as np 
import pandas as pd 
import matplotlib as plt
from matplotlib.animation import FuncAnimation
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

df_d = pd.read_csv('../input/coviddatasets/CovidDeaths1a.csv')
df_v = pd.read_csv('../input/coviddatasets/CovidVaccinations1a.csv')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /kaggle/input/coviddatasets/CovidDeaths1a.csv
# /kaggle/input/coviddatasets/CovidVaccinations1a.csv

# %% [markdown]
# **Looking at each data table:**

# %%
df_d.head()
# Out:
#   iso_code continent     location        date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03  41128772.0          NaN
# 1      AFG      Asia  Afghanistan  2020-01-04  41128772.0          NaN
# 2      AFG      Asia  Afghanistan  2020-01-05  41128772.0          NaN
# 3      AFG      Asia  Afghanistan  2020-01-06  41128772.0          NaN
# 4      AFG      Asia  Afghanistan  2020-01-07  41128772.0          NaN
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        0.0                 NaN           NaN         0.0  ...
# 1        0.0                 NaN           NaN         0.0  ...
# 2        0.0                 NaN           NaN         0.0  ...
# 3        0.0                 NaN           NaN         0.0  ...
# 4        0.0                 NaN           NaN         0.0  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# ...

# %%
df_v.head()
# Out:
#   iso_code continent     location        date  total_tests  new_tests  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        NaN
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        NaN
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        NaN
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        NaN
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  ...  male_smokers  handwashing_facilities  \
# ...

# %% [markdown]
# ### Meta Data  -- Studying the Schema
# Looking at datatypes and if there are null data types. Exploring data dimensions. Changing datatypes as needed.

# %%
df_d.info()
df_d.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330736 entries, 0 to 330735
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   iso_code                            330736 non-null  object
#  1   continent                           315032 non-null  object
#  2   location                            330736 non-null  object
#  3   date                                330736 non-null  object
#  4   population                          330736 non-null  float64
#  5   total_cases                         293300 non-null  float64
#  6   new_cases                           321633 non-null  float64
#  7   new_cases_smoothed                  320374 non-null  float64
#  8   total_deaths                        272174 non-null  float64
#  9   new_deaths                          321702 non-null  float64
#  10  new_deaths_smoothed                 320472 non-null  float64
# ...

# %%
df_v.info()
df_v.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330736 entries, 0 to 330735
# Data columns (total 46 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    330736 non-null  object
#  1   continent                                   315032 non-null  object
#  2   location                                    330736 non-null  object
#  3   date                                        330736 non-null  object
#  4   total_tests                                 79387 non-null   float64
#  5   new_tests                                   75403 non-null   float64
#  6   total_tests_per_thousand                    79387 non-null   float64
#  7   new_tests_per_thousand                      75403 non-null   float64
#  8   new_tests_smoothed                          103965 non-null  float64
# ...

# %% [markdown]
# Dimensions (rows, columns) of two data sets:

# %%
display(df_d.shape)
display(df_v.shape)
# Out:
# (330736, 26)
# (330736, 46)

# %% [markdown]
# Changing object datatypes to string and datetime for both datasets:

# %%
#vaccine data set
df_v_columns = ['iso_code', 'continent','location','tests_units']
df_v[df_v_columns] = df_v[df_v_columns].astype('string')
print(df_v.dtypes)
df_v_datetime = ['date']
df_v[df_v_datetime]=df_v[df_v_datetime].apply(pd.to_datetime)
display(df_v.dtypes)

#death data set 

df_d_columns = ['iso_code', 'continent','location']
df_d[df_d_columns] = df_d[df_d_columns].astype('string')
print(df_d.dtypes)
df_d_datetime = ['date']
df_d[df_d_datetime]=df_d[df_d_datetime].apply(pd.to_datetime)
display(df_d.dtypes)
# Out:
# iso_code                                       string
# continent                                      string
# location                                       string
# date                                           object
# total_tests                                   float64
# new_tests                                     float64
# total_tests_per_thousand                      float64
# new_tests_per_thousand                        float64
# new_tests_smoothed                            float64
# new_tests_smoothed_per_thousand               float64
# positive_rate                                 float64
# tests_per_case                                float64
# tests_units                                    string
# total_vaccinations                            float64
# people_vaccinated                             float64
# people_fully_vaccinated                       float64
# total_boosters                                float64
# ...

# %% [markdown]
# **Joining tables:**

# %%
d_v_tables = pd.merge(df_d, df_v, on=['location','date'],how ='inner')
display(d_v_tables)
# Out:
#        iso_code_x continent_x     location       date  population  \
# 0             AFG        Asia  Afghanistan 2020-01-03  41128772.0
# 1             AFG        Asia  Afghanistan 2020-01-04  41128772.0
# 2             AFG        Asia  Afghanistan 2020-01-05  41128772.0
# 3             AFG        Asia  Afghanistan 2020-01-06  41128772.0
# 4             AFG        Asia  Afghanistan 2020-01-07  41128772.0
# ...           ...         ...          ...        ...         ...
# 330731        ZWE      Africa     Zimbabwe 2023-07-29  16320539.0
# 330732        ZWE      Africa     Zimbabwe 2023-07-30  16320539.0
# 330733        ZWE      Africa     Zimbabwe 2023-07-31  16320539.0
# 330734        ZWE      Africa     Zimbabwe 2023-08-01  16320539.0
# 330735        ZWE      Africa     Zimbabwe 2023-08-02  16320539.0
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0               NaN        0.0                 NaN           NaN         0.0
# ...

# %%
display(d_v_tables)
# Out:
#        iso_code_x continent_x     location       date  population  \
# 0             AFG        Asia  Afghanistan 2020-01-03  41128772.0
# 1             AFG        Asia  Afghanistan 2020-01-04  41128772.0
# 2             AFG        Asia  Afghanistan 2020-01-05  41128772.0
# 3             AFG        Asia  Afghanistan 2020-01-06  41128772.0
# 4             AFG        Asia  Afghanistan 2020-01-07  41128772.0
# ...           ...         ...          ...        ...         ...
# 330731        ZWE      Africa     Zimbabwe 2023-07-29  16320539.0
# 330732        ZWE      Africa     Zimbabwe 2023-07-30  16320539.0
# 330733        ZWE      Africa     Zimbabwe 2023-07-31  16320539.0
# 330734        ZWE      Africa     Zimbabwe 2023-08-01  16320539.0
# 330735        ZWE      Africa     Zimbabwe 2023-08-02  16320539.0
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0               NaN        0.0                 NaN           NaN         0.0
# ...

# %% [markdown]
# **Exploring Count of New Covid-19 Deaths by Month:**

# %%
d_v_tables['month'] = d_v_tables['date'].dt.strftime('%b %Y')
sns.set(style='whitegrid')
plt.figure(figsize=(10,6))
ax=sns.barplot(x='month',y='new_deaths',data=d_v_tables,palette='Set2')
plt.xticks(rotation=45,ha='right')
ax.set_xticklabels(ax.get_xticklabels(), fontdict={'fontsize': 8, 'fontweight': 'normal'})
plt.subplots_adjust(bottom=0.2)

# %% [markdown]
# **Exploring Count of New Covid-19 Cases by Month:**

# %%
 
d_v_tables.dropna(subset=['new_cases'],inplace=True)

d_v_tables['new_cases']=pd.to_numeric(d_v_tables['new_cases'])
d_v_tables['month']=d_v_tables['date'].dt.strftime('%b %Y')

sns.set(style='whitegrid')
plt.figure(figsize=(12,8))
ax=sns.barplot(x='month',y='new_cases',data=d_v_tables,palette='Set2')
plt.xticks(rotation=45,ha='right')
ax.set_xticklabels(ax.get_xticklabels(),fontdict={'fontsize':6,'fontweight': 'normal'})
plt.subplots_adjust(bottom=.3)
plt.show()

# %% [markdown]
# **New Cases By Continent:**

# %%
continent_cases_sum = d_v_tables.groupby('continent_x')['new_cases'].sum().reset_index()
total_cases = continent_cases_sum['new_cases'].sum()
continent_cases_sum['percentage_cases'] = (continent_cases_sum['new_cases'] / total_cases) * 100
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='continent_x', y='percentage_cases', data=continent_cases_sum, color='blue')
ax.set_xlabel('Continent')
ax.set_ylabel('Percentage of New Cases by Continent')
ax.set_title('Percentage of COVID-19 New Cases by Continent')
plt.xticks(rotation=45)
ax.yaxis.set_major_formatter(mticker.PercentFormatter(decimals=2))
plt.tight_layout()
plt.show()

# %% [markdown]
# **Total New Deaths From Covid By Continent**

# %%
# Calculate the total deaths
total_deaths = d_v_tables['new_deaths'].sum()

# Group by 'continent_x' and calculate the total deaths for each continent
continent_deaths_sum = d_v_tables.groupby('continent_x')['new_deaths'].sum().reset_index()

# Calculate the percentage of deaths for each continent based on the total deaths
continent_deaths_sum['percentage_deaths'] = (continent_deaths_sum['new_deaths'] / total_deaths) * 100

# Create a bar plot to compare the percentage of deaths by continent
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='continent_x', y='percentage_deaths', data=continent_deaths_sum, color='red')
ax.set_xlabel('Continent')
ax.set_ylabel('Percentage of New Deaths by Continent')
ax.set_title('Percentage of COVID-19 New Deaths by Continent')
plt.xticks(rotation=45)
ax.yaxis.set_major_formatter(mticker.PercentFormatter(decimals=2))
plt.tight_layout()
plt.show()

# %% [markdown]
# **Comparison of Trends of People Fully Vaccinated in the United States, India and France**

# %%
desired_locations = ['France', 'United States', 'India']  # Add more countries as needed

# # Create a new figure and axis
# plt.figure(figsize=(10, 6))

# # Iterate through locations:
# for desired_location in desired_locations:
#     current_population = d_v_tables.loc[d_v_tables['location'] == desired_location, 'population'].values[0]
    
#     # Filter data 
#     filtered_data = d_v_tables[(d_v_tables['location'] == desired_location) & (d_v_tables['people_fully_vaccinated'] != '')]
#     filtered_data['month'] = filtered_data['date'].dt.strftime('%b %Y')
#     filtered_data['rnk'] = filtered_data.groupby(['location', 'month'])['people_fully_vaccinated'].rank(method='max', ascending=False)
#     ranked_data = filtered_data[(filtered_data['rnk'] == 1) & (filtered_data['location'] == desired_location)]

#     # Calculate the percentage of people fully vaccinated based on the population
#     ranked_data['percentage_fully_vaccinated'] = (ranked_data['people_fully_vaccinated'].astype(int) / current_population) * 100

#     result = ranked_data[['location', 'month', 'percentage_fully_vaccinated']]
#     result = result.sort_values(by=['location', 'month'])

#     # Plot the percentage of people fully vaccinated for the current location
#     plt.plot(result['month'], result['percentage_fully_vaccinated'], marker='o', label=desired_location)

# #Labels and title
# plt.xlabel('Month')
# plt.ylabel('Percentage of People Fully Vaccinated (%)')
# plt.title('Percentage of People Fully Vaccinated Over Time')
# plt.xticks(rotation=45)
# plt.gca().yaxis.set_major_formatter(mticker.ScalarFormatter(useMathText=True, useOffset=False))
# plt.legend()  # Add a legend to differentiate lines

# # Display 
# plt.tight_layout()
# plt.show()

# Create a new figure and axis
plt.figure(figsize=(10, 6))

# Iterate through locations:
for desired_location in desired_locations:
    current_population = d_v_tables.loc[d_v_tables['location'] == desired_location, 'population'].values[0]
    
    # Filter data 
    filtered_data = d_v_tables[(d_v_tables['location'] == desired_location) & (d_v_tables['people_fully_vaccinated'] != '')]
    filtered_data['month'] = filtered_data['date'].dt.strftime('%b %Y')
    filtered_data['rnk'] = filtered_data.groupby(['location', 'month'])['people_fully_vaccinated'].rank(method='max', ascending=False)
    ranked_data = filtered_data[(filtered_data['rnk'] == 1) & (filtered_data['location'] == desired_location)]

    # Calculate the percentage of people fully vaccinated based on the population
    ranked_data.loc[:, 'percentage_fully_vaccinated'] = (ranked_data['people_fully_vaccinated'].astype(int) / current_population) * 100

    result = ranked_data[['location', 'month', 'percentage_fully_vaccinated']]
    
    # Sort the 'month' column chronologically
    result['date'] = pd.to_datetime(result['month'], format='%b %Y')
    result = result.sort_values(by='date')
    
    # Plot the percentage of people fully vaccinated for the current location
    plt.plot(result['month'], result['percentage_fully_vaccinated'], marker='o', label=desired_location)

# Labels and title
plt.xlabel('Month')
plt.ylabel('Percentage of People Fully Vaccinated (%)')
plt.title('Percentage of People Fully Vaccinated Over Time')
plt.xticks(rotation=45)
plt.gca().yaxis.set_major_formatter(mticker.ScalarFormatter(useMathText=True, useOffset=False))
plt.legend()  # Add a legend to differentiate lines

# Display 
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_32/3378838406.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['month'] = filtered_data['date'].dt.strftime('%b %Y')
# /tmp/ipykernel_32/3378838406.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['rnk'] = filtered_data.groupby(['location', 'month'])['people_fully_vaccinated'].rank(method='max', ascending=False)
# /tmp/ipykernel_32/3378838406.py:51: SettingWithCopyWarning:
# ...

# %% [markdown]
# **Distribution of new vaccinations over time by continent using a stacked area chart:**

# %%
vaccination_data = d_v_tables.groupby(['date','continent_x'])['new_vaccinations'].sum().reset_index()
pivot_vaccination_data=vaccination_data.pivot(index='date', columns='continent_x',values='new_vaccinations')
plt.figure(figsize=(10,6))
pivot_vaccination_data.plot(kind='line',linewidth=1)
plt.xlabel('Date')
plt.ylabel('Number of New Vaccinations')
plt.title('Distribution of New Vaccinations Over Time By Continent')
plt.legend()
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **KEY TAKEAWAYS**
#
# By completing this project I was able to learn more about the impact of Covid-19 in the world and in specific countries via exploratory data analysis and visualization. I was able to look at data distribution as well as explore correlations between different Covid-19 variables.

# %% [markdown]
# **Summary of Findings**
# * **Deaths/Month:** The data shows that the most deaths per month occurred in January of 2021 which was before the majority of individuals had vaccines.
# * **Cases/Month:** In the early part of 2022 there were the most new cases recorded; in January 50,000 cases were recorded worldwide.
# * **Count New Vaccinations** Between May 2021 and December 2021  the majority of vaccinations worldwide administered. Specifically 1,000,000 and 1,600,000 vaccinations were administered.
# * **Cases By Contintent** Asia had the most reported Covid-19 compared with other contintents. This aligns with the fact that they Asia is densly populated.
# * **Deaths By Continent** Europe had more deaths due to Covid-19 than Asia. Perhaps Asia was better at implementing safety precautions, or Asians tend to be healthier than Europeans.
# * **Comparing Vaccinations in US, France and India:** In France there was an upswing of people who became vaccinated April through September of 2021. In the US by May 2021 there was a drop off in the amount of people becoming vaccinated. Folks in India continued to get vaccinated until January 2022 and then it leveled off.
# * **Vaccinations By Continent:** Most continents vaccinated individuals July 2021 through January 22. The US started vaccinating individuals earlier in January 2021.
